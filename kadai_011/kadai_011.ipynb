# %%
#forを用いて繰り返し処理を記述する
array_lists = ["水","金","地","火","木","土","天","海","冥"]
for array in array_lists:
  print(array)

#whileを用いて繰り返し処理を記述する
i = 0;
while(i<9):
  print(array_lists[i])
  i = i + 1
# Out:
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
